# %% [markdown]
# # 01. Python 핵심 문법
# **SK하이닉스 Autonomous R&D — Day 1**
#
# > AI가 만든 코드를 읽고, 고칠 수 있는 수준이 목표입니다.

# %% [markdown]
# ---
# ## 1. 변수와 자료형

# %%
# 변수 선언 — 값을 담는 그릇

# %%
# 제조 데이터 예제

# %%
# 형변환

# %%
# 기본 연산

# %% [markdown]
# ---
# ## 2. 문자열

# %%
# 선언 방법

# %%
# 인덱싱 & 슬라이싱

# %%
# 문자열 메서드

# %%
# f-string

# %%
# 문자열 + 숫자 결합

# %% [markdown]
# ---
# ## 3. 리스트 (List)
# 여러 데이터를 순서대로 담습니다. Cursor 코드의 절반 이상이 `data = []` 패턴입니다.

# %%
# 리스트 생성

# %%
# 인덱싱 & 슬라이싱

# %%
# 리스트 함수

# %%
# append / insert / extend

# %%
# in 연산자

# %% [markdown]
# ---
# ## 4. 조건문 (if)

# %%
# 기본 if - else

# %%
# if - elif - else

# %%
# 짝수/홀수 판별 (나머지 % 활용)

# %%
# 복합 조건  and / or / in

# %%
# 불량 판정 — 실전 패턴

# %% [markdown]
# ---
# ## 5. 반복문 (for)
# `for`는 AI 코드에서 가장 많이 등장합니다.

# %%
# 기본 for

# %%
# range — 숫자 반복
# 1~10 합계

# %%
# 1~100에서 3의 배수 합

# %%
# enumerate — 인덱스와 값 함께

# %%
# for + if + append

# %%
# List Comprehension — 같은 결과, 더 짧게
# 응용: 제곱수 리스트

# %%
# while — 조건이 참인 동안 반복

# %% [markdown]
# ---
# ## 6. 딕셔너리 (Dictionary)
# 키-값 쌍으로 데이터를 저장합니다.

# %%
# 딕셔너리 생성 — 키:값 쌍

# %%
# keys / values / items

# %%
# 추가 / 수정 / 삭제

# %%
# 딕셔너리로 농담 사전 만들기 (원본 그대로)

# %%
# 키 목록 / 값 목록

# %%
# for + items()

# %%
# 딕셔너리로 빈도 집계 — 자주 쓰는 패턴

# %% [markdown]
# ---
# ## 7. 함수 (Function)

# %%
# 기본 함수

# %%
# 두 값 중 큰 것 반환

# %%
# 기본값 인수 + 제조 예제

# %%
# 여러 값 반환

# %%
# 실전 패턴: 분석 결과를 딕셔너리로 반환

# %% [markdown]
# ---
# ## 8. import & 라이브러리

# %%
# import — AI 코드의 첫 줄은 항상 import

# %%
# numpy 맛보기 (다음 시간에 자세히)

# %% [markdown]
# ---
# ## 9. 클래스 (Class)
# 데이터(속성)와 기능(메서드)을 묶은 설계도입니다.
# 하나 만들어두면 객체를 여러 개 찍어낼 수 있습니다.

# %%
# 클래스 기본 구조 — Employee

# %%
# 같은 클래스로 객체를 여러 개 만들 수 있다

# %%
# 설비 클래스 — 처리 이력 관리

# %%
# reset() 호출

# %%
# 설비 두 대 동시 운영

# %%
# 상태(status)를 가진 클래스

# %%
# Day 2에서 보게 될 Agent 패턴

# %% [markdown]
# ---
# ## ✏️ 과제 1 — 설비별 평균 수율
#
# 아래 `lot_data`에서 **설비별 평균 수율**을 딕셔너리로 만들어보세요.
#
# ```
# 예상 결과:
# EQ1: 85.75%
# EQ2: 85.25%
# EQ3: 99.0%
# ```
#
# 힌트: `eq_sum = {}` / `eq_cnt = {}` 로 시작하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ---
# ### 💡 과제 1 — 정답
# > 풀어본 후에 아래 셀을 실행하세요.

# %%
# ── 정답 ──────────────────────────────────────────────────
# ── Pandas 배우고 나면 한 줄로 ─────────────────────────────# import pandas as pd# df = pd.DataFrame(lot_data)# print(df.groupby('Equip_ID')['Yield'].mean().round(2))
