# %% [markdown]
# # Tool과 Sub-Agent
# * **LLM 토론 그래프**에 **Tool**과 **Sub-Agent**를 연결합니다.

# %% [markdown]
# ---
# * `day15` Conda 환경을 사용합니다.
# * 웹 검색·주가 조회 패키지를 추가로 설치합니다.

# %%
# !pip install langchain langchain-openai ddgs yfinance
# Out:
# Requirement already satisfied: langchain in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (1.3.11)
# Requirement already satisfied: langchain-openai in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (1.3.3)
# Requirement already satisfied: ddgs in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (9.14.4)
# Requirement already satisfied: yfinance in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (1.5.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langchain) (1.4.8)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langchain) (1.2.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.9.2)
# Requirement already satisfied: packaging>=23.2.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.7.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (4.14.1)
# Requirement already satisfied: distro>=1.7.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (0.25.0)
# Requirement already satisfied: certifi in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langchain-openai) (2.44.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.15.0)
# Requirement already satisfied: tqdm>4 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.68.3)
# Requirement already satisfied: regex in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.5.9)
# Requirement already satisfied: click>=8.1.8 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from ddgs) (8.4.2)
# Requirement already satisfied: primp>=1.2.3 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from ddgs) (1.3.1)
# Requirement already satisfied: lxml>=4.9.4 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from ddgs) (6.1.1)
# Requirement already satisfied: fake-useragent>=2.2.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from ddgs) (2.2.0)
# Requirement already satisfied: pandas>=1.3.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from yfinance) (2.3.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from yfinance) (4.10.0)
# Requirement already satisfied: pytz>=2022.5 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: peewee>=3.16.2 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from yfinance) (4.1.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from yfinance) (4.15.0)
# Requirement already satisfied: curl_cffi>=0.15 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from yfinance) (7.35.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.4)
# Requirement already satisfied: cffi>=2.0.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from curl_cffi>=0.15->yfinance) (2.1.0)
# Requirement already satisfied: rich in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from curl_cffi>=0.15->yfinance) (15.0.0)
# Requirement already satisfied: pycparser in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: brotli in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.3.0)
# Requirement already satisfied: socksio==1.* in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2026.2)
# Requirement already satisfied: six>=1.5 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (2.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from rich->curl_cffi>=0.15->yfinance) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from rich->curl_cffi>=0.15->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/seorincho/opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.2)

# %%
import json
from pathlib import Path
from dotenv import load_dotenv

load_dotenv()
OPENAI_API_KEY = __import__('os').getenv('OPENAI_API_KEY')

WORKDIR = Path.cwd()

print('WORKDIR :', WORKDIR)
# Out:
# WORKDIR : /Users/seorincho/Desktop/code/2026_AI/SK Autonomous R&D/16일차

# %% [markdown]
# ---
# ## Tool 준비

# %%
import yfinance as yf
from ddgs import DDGS
from ddgs.exceptions import DDGSException
from langchain.tools import tool

@tool
def web_search(query: str) -> str:
    """최신 뉴스·시사·웹 정보를 검색합니다. 질문이나 키워드를 넣어 검색하세요.""" # @tool의 설명은 llm에게 전달되므로 자세히 작성
    try:
        with DDGS() as ddgs:
            results = list(ddgs.text(query, max_results=3))
            print(f"검색 수행 완료. query: {query}")
    except DDGSException:
        # ddgs는 결과 0건·일시 차단 시 예외를 던짐 → LLM에게 문자열로 전달
        return f'검색 결과 없음 (query: {query})'
    if not results:
        return '검색 결과 없음'
    return json.dumps(results, ensure_ascii=False)

print(web_search.name)
# Out:
# web_search

# %%
# Tool 단독 테스트
print('=== 웹 검색 ===')
print(web_search.invoke('AI chip market 2026')[:400])
# Out:
# === 웹 검색 ===
# 검색 수행 완료. query: AI chip market 2026
# [{"title": "AI Chip Market Report 2026 - Research and Markets", "href": "https://www.researchandmarkets.com/reports/6226133/ai-chip-market-report", "body": "It will grow from $61.83 billion in 2025 to $84.17 billion in 2026 at a compound annual growth rate (CAGR) of 36.1%. The growth in the historic period can be attributed to increasing use of artificial intelligence in cloud computing, growing .

# %% [markdown]
# ---
# ## 웹 검색 근거 토론
#
# 15.3의 `optimist` / `skeptic` 토론에 **DuckDuckGo**를 붙입니다.
#
# Tool을 쓰는 방법은 크게 두 가지입니다.
#
# | 방식 | 핵심 | 장점 |
# |------|------|------|
# | **A. 노드 내부 Tool** | Node 안에서 Tool 포함한 Agent 실행 | 단일 노드에서만 tool을 사용하는 경우 편리 |
# | **B. `ToolNode`** | Tool 실행을 **별도 Node**로 분리 | 그래프에서 도구 사용을 제어 가능 |

# %%
from typing import Annotated, Literal

from pydantic import BaseModel, Field
from langgraph.graph.message import add_messages
from langchain_core.messages import BaseMessage, HumanMessage, SystemMessage, ToolMessage # -> Tool 사용과 관련된 메시지
from langchain_openai import ChatOpenAI


class ToolDebateState(BaseModel):
    messages: Annotated[list[BaseMessage], add_messages] = Field(default_factory=list)
    topic: str
    turn_count: int = 0
    max_turns: int = 2
    last_speaker: Literal['optimist', 'skeptic'] = 'skeptic'

TOOLS = [web_search]
TOOLS_BY_NAME = {t.name: t for t in TOOLS}

# %% [markdown]
# ### 방식 A — create_agent 활용
#
# * 노드 내부에서 `create_agent`를 이용해 에이전트를 생성하고, LLM과 Tool을 함께 실행
# * LLM이 Tool 사용 요청을 하면, 해당 Tool이 자동으로 호출되어 결과가 LLM에게 전달되는 과정을 create_agent가 처리
# * 토론 참가자가 응답을 완료하거나 추가 Tool 호출이 없다면, 생성된 응답을 토론 history에 기록
#
# 단일 노드에서 Tool 사용이 필요한 경우 create_agent 방식이 가장 간단함

# %%
from langchain.agents import create_agent

search_agent = create_agent(
    model="openai:gpt-4o-mini",
    tools=TOOLS,
)

# %%
def optimist_bind_node(state: ToolDebateState) -> dict:
    prompts = [
        SystemMessage(content=(
            "당신은 세계 최고의 AI 토론가입니다."
            "주어지는 주제에 '찬성' 입장에서 토론에 참가하세요."
            "상대 AI 토론자의 의견에 조리 있게 두 문장 이내로 반박하세요"
            "'web_search' 도구를 활용해 웹 검색을 수행하면 질 좋은 근거를 얻을 수 있습니다."
            "응답 시 상대 AI 토론자와 대화하는 방식으로 응답하세요"
            "응답에 '패배 인정'을 포함하면 패배를 인정하고 토론을 끝낼 수 있습니다."
        )),
    ]
    if not state.messages:
        prompts.append(HumanMessage(content=f'토론 주제: {state.topic}'))
    else:
        prompts.extend(state.messages)

    response = search_agent.invoke({'messages': prompts})['messages'][-1]
    response.name = 'optimist'
    return {
        'messages': [response],
        'last_speaker': 'optimist',
        'turn_count': state.turn_count + 1,
    }


def skeptic_bind_node(state: ToolDebateState) -> dict:
    prompts = [
        SystemMessage(content=(
             "당신은 세계 최고의 AI 토론가입니다."
            "주어지는 주제에 '반대' 입장에서 토론에 참가하세요."
            "상대 AI 토론자의 의견에 조리 있게 두 문장 이내로 반박하세요"
            "'web_search' 도구를 활용해 웹 검색을 수행하면 질 좋은 근거를 얻을 수 있습니다."
            "응답 시 상대 AI 토론자와 대화하는 방식으로 응답하세요"
            "응답에 '패배 인정'을 포함하면 패배를 인정하고 토론을 끝낼 수 있습니다."
        )),
        *state.messages,
    ]
    response = search_agent.invoke({'messages': prompts})['messages'][-1]
    response.name = 'skeptic'
    return {
        'messages': [response],
        'last_speaker': 'skeptic',
    }

# %%
from langgraph.graph import StateGraph, START, END


def tool_debate_route(state: ToolDebateState):
    if state.turn_count >= state.max_turns:
        return END
    last_text = state.messages[-1].content if state.messages else ''
    if '합의' in last_text:
        return END
    return 'optimist_bind'


bind_workflow = StateGraph(ToolDebateState)
bind_workflow.add_node('optimist_bind', optimist_bind_node)
bind_workflow.add_node('skeptic_bind', skeptic_bind_node)
bind_workflow.add_edge(START, 'optimist_bind')
bind_workflow.add_edge('optimist_bind', 'skeptic_bind')
bind_workflow.add_conditional_edges('skeptic_bind', tool_debate_route)

bind_debate_app = bind_workflow.compile()

# %%
for chunk in bind_debate_app.stream(ToolDebateState(topic='K팝 산업은 더욱 성장할 것이다')):
    print(chunk)
# Out:
# {'optimist_bind': {'messages': [AIMessage(content='K팝 산업은 더욱 성장할 것입니다. 글로벌 시장에서 K팝의 인기가 증가하고 있으며, 많은 아티스트들이 국제 활동을 활발히 펼치고 있기 때문입니다. \n\n여기에 대해 어떻게 생각하십니까?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 186, 'total_tokens': 238, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8c62eb5aea', 'id': 'chatcmpl-E138iybmz0aOq9DvwD4MsUdAuKYwi', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='optimist', id='lc_run--019f59dd-4d3c-7e31-845c-897c30236a8c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 186, 'output_tokens': 52, 'total_tokens': 238, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'last_speaker': 'optimist', 'turn_count': 1}}
# {'skeptic_bind': {'messages': [AIMessage(content='K팝 산업은 현재 많은 인기를 끌고 있지만, 그 지속 가능성에 의문을 제기할 수 있습니다. 팬덤 문화가 지나치게 상업화되며 멤버들의 정신적, 신체적 압박이 커지는 상황에서, 앞으로의 성장은 불투명할 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 70, 'prompt_tokens': 226, 'total_tokens': 296, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E138jd0n5N7k5aU0BDmyUe8YJIA3S', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='skeptic', id='lc_run--019f59dd-5557-7dd3-9fcf-7ec07de8a2d6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 226, 'output_tokens': 70, 'total_tokens': 296, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'last_speaker': 'skeptic'}}
# {'optimist_bind': {'messages': [AIMessage(content='K팝의 인기는 그간의 지속적인 글로벌 성과로 입증되었습니다. 팬덤은 강력한 유대감을 형성하며 아티스트의 도전과 어려움을 지지하는 기반이 있어, 오히려 긍정적인 영향을 미칠 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 302, 'total_tokens': 363, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8c62eb5aea', 'id': 'chatcmpl-E138lZWGzxJXYCE8KRufjEkhXjWfj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='optimist', id='lc_run--019f59dd-5c7e-7bb1-a709-969a68a2b607-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 302, 'output_tokens': 61, 'total_tokens': 363, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'last_speaker': 'optimist', 'turn_count': 2}}
# {'skeptic_bind': {'messages': [AIMessage(content='K팝 팬덤의 유대감은 긍정적일 수 있지만, 지나치게 몰입한 팬덤 문화가 특정 아티스트에게 압박을 가할 수도 있습니다. 이는 결국 아티스트의 건강과 경력에 부정적인 영향을 미칠 수 있으며, 산업 전체의 지속 가능성에 위협이 될 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 76, 'prompt_tokens': 369, 'total_tokens': 445, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E138n1SXgSOauZgOCalA2bCX8oAi1', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='skeptic', id='lc_run--019f59dd-64db-77e3-baa7-f5d88d75da59-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 369, 'output_tokens': 76, 'total_tokens': 445, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'last_speaker': 'skeptic'}}

# %% [markdown]
# ### 방식 B — `ToolNode` + `tools_condition`
#
# * **agent Node**: `bind_tools` LLM이 `tool_calls` 를 내놓을 수 있음
# * **tools Node**: `ToolNode`가 실제 검색 실행
# * **tools_condition**: `tool_calls` 있으면 `tools` Node, 없으면 `END`

# %%
from langgraph.prebuilt import ToolNode


class ReactState(BaseModel):
    messages: Annotated[list[BaseMessage], add_messages] = Field(default_factory=list)
    topic: str
    turn_count: int = 0
    max_turns: int = 3
    last_speaker: Literal['optimist', 'skeptic'] = 'skeptic'

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

react_llm = llm.bind_tools([web_search])

# %%
# bind_tools 을 수행하면 바인딩한 도구를 사용하겠다는 응답(.tool_calls)을 받을 수 있음
react_llm.invoke([HumanMessage(content=f"도구를 사용해 2026 월드컵 결과 확인")]).tool_calls
# Out:
# [{'name': 'web_search',
#   'args': {'query': '2026 월드컵 결과'},
#   'id': 'call_daI2OViBlC7HguNp5YykmyUz',
#   'type': 'tool_call'}]

# %%
def react_optimist_node(state: ReactState) -> dict:
    prompts = [
        SystemMessage(content=(
            "당신은 세계 최고의 AI 토론가입니다."
            "주어지는 주제에 '찬성' 입장에서 토론에 참가하세요."
            "상대 AI 토론자의 의견에 조리 있게 두 문장 이내로 반박하세요"
            "'web_search' 도구를 활용해 웹 검색을 수행하면 질 좋은 근거를 얻을 수 있습니다."
            "응답 시 상대 AI 토론자와 대화하는 방식으로 응답하세요"
            "응답에 '패배 인정'을 포함하면 패배를 인정하고 토론을 끝낼 수 있습니다."
        )),]

    if not state.messages:
        prompts.append(HumanMessage(content=f'토론 주제: {state.topic}'))
    else:
        prompts.extend(state.messages)
    
    response = react_llm.invoke(prompts)

    
    return {'messages': [response], 'last_speaker': 'optimist', 'turn_count': state.turn_count + 1}

def react_skeptic_node(state: ReactState) -> dict:
    prompts = [
        SystemMessage(content=(
            "당신은 세계 최고의 AI 토론가입니다."
            "주어지는 주제에 '반대' 입장에서 토론에 참가하세요."
            "상대 AI 토론자의 의견에 조리 있게 두 문장 이내로 반박하세요"
            "'web_search' 도구를 활용해 웹 검색을 수행하면 질 좋은 근거를 얻을 수 있습니다."
            "응답 시 상대 AI 토론자와 대화하는 방식으로 응답하세요"
            "응답에 '패배 인정'을 포함하면 패배를 인정하고 토론을 끝낼 수 있습니다."
        )), ]

    prompts.extend(state.messages)

    response = react_llm.invoke(prompts)
    return {'messages': [response], 'last_speaker': 'skeptic'}

# %%
react_workflow = StateGraph(ReactState)

react_workflow.add_node('optimist', react_optimist_node)
react_workflow.add_node('skeptic', react_skeptic_node)
react_workflow.add_node('tools', ToolNode([web_search])) # tool 사용을 담당하는 prebuilt 노드


react_workflow.add_edge(START, 'optimist')

def route_after_optimist(state: ReactState):
    if state.messages[-1].tool_calls: # tool_calls가 존재하는 경우
        return 'tools' # tool 노드로 이동
    last_text = state.messages[-1].content or ''
    if '패배 인정' in last_text:
        return END
    return 'skeptic' # tool 사용하지 않는 경우, 그대로 상대에게 차례를 넘김

def route_after_skeptic(state: ReactState):
    if state.messages[-1].tool_calls:
        return 'tools'
    if state.turn_count >= state.max_turns:
        return END
    last_text = state.messages[-1].content or ''
    if '패배 인정' in last_text:
        return END
    return 'optimist'

def route_after_tools(state: ReactState):
    if state.last_speaker == 'optimist':
        return 'optimist'
    else:
        return 'skeptic'

react_workflow.add_conditional_edges('optimist', route_after_optimist)
react_workflow.add_conditional_edges('skeptic', route_after_skeptic)
react_workflow.add_conditional_edges('tools', route_after_tools)

react_app = react_workflow.compile()

# %%
init_state = ReactState(
    topic="2024-2025 전기차 판매 통계를 바탕으로 전기차의 미래에 대해 토론"
)
for chunk in react_app.stream(init_state):
    print(chunk)
# Out:
# {'optimist': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 201, 'total_tokens': 224, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8c62eb5aea', 'id': 'chatcmpl-E159o3N5mCwK1DcyfwpMIC8VYbxCe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f5a53-a435-7293-9ba5-38efa4ff6f94-0', tool_calls=[{'name': 'web_search', 'args': {'query': '2024-2025 electric vehicle sales statistics forecast'}, 'id': 'call_a9Py6NANXc3caC9NMfggz6eL', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 201, 'output_tokens': 23, 'total_tokens': 224, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'last_speaker': 'optimist', 'turn_count': 1}}
# 검색 수행 완료. query: 2024-2025 electric vehicle sales statistics forecast
# {'tools': {'messages': [ToolMessage(content='[{"title": "Electricity – Global Energy Review 2025 – Analysis - IEA", "href": "https://www.iea.org/reports/global-energy-review-2025/electricity", "body": "Technology: Electric vehicles. Electric car sales continued to rise globally in 2024, increasing by more than 25% to more than 17 million units, up from below 14 million units in 2023. This aligns with the IEA’s preliminary estimate for annual sales in the 2024 edition of the Global EV..."}, {"title": "Tracking global data on electric vehicles | Our World in Data", "href": "https://ourworldindata.org/electric-car-sales", "body": "Sales of electric cars started from a low base but are growing quickly in many markets. Globally, one in four new cars sold in 2025 was electric.Hannah Ritchie (2024) - “Tracking global data on electric vehicles” Published online at OurWorldinData.org."}, {"title": "Statista - The Statistics Portal for Market Data, Market Research and...", "href": "https://www.statista.com/", "body": "Electric vehicles worldwide - statistics & facts.Recent Statistics Popular Statistics. Top pharma companies - Rx sales and R&D spending 2024. Worldwide pharmaceutical R&D spending 2016-2030."}]', name='web_search', id='48705552-40fe-4ccd-926e-879a21c6b63c', tool_call_id='call_a9Py6NANXc3caC9NMfggz6eL')]}}
# {'optimist': {'messages': [AIMessage(content='전기차는 미래의 지속 가능한 교통 수단으로, 판매량이 매년 기하급수적으로 증가하고 있습니다. 2024년에는 전 세계에서 1,700만 대 이상의 전기차가 판매될 것으로 예상되며, 이는 전 세계적으로 점점 더 많은 소비자들이 전기차를 선택하고 있음을 나타냅니다. \n\n상대방, 전기차 판매 증가에 대한 의문을 제기할 수 있지만, 이러한 통계는 시장의 수요와 전환 속도를 명확히 보여줍니다. 그 어느 때보다 각국의 정책 및 정부 지원이 전기차 구매를 장려하고 있다는 사실도 간과할 수 없는 중요한 요소입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 152, 'prompt_tokens': 481, 'total_tokens': 633, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8c62eb5aea', 'id': 'chatcmpl-E159wAuEA2n2e9rDT5aQk0FqFGdOS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f5a53-c66a-7212-8156-7d08deddc06b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 481, 'output_tokens': 152, 'total_tokens': 633, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'last_speaker': 'optimist', 'turn_count': 2}}
# {'skeptic': {'messages': [AIMessage(content='상대 AI 토론자가 전기차 판매 증가의 긍정적인 측면에 대해 언급했죠. 그러나 전기차의 성장세에도 불구하고, 전기차 생산에 필요한 자원 채굴과 폐기물 처리 문제를 포함한 환경적 문제가 해결되지 않는 한 진정한 지속 가능성을 주장하기는 어렵습니다. \n\n지속적인 자원 수요와 관련하여 생태계에 미치는 영향을 간과할 수 없으며, 배터리 재활용 문제도 해결되지 않았다면 이러한 긍정적인 전망은 너무 단순한 접근일 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 129, 'prompt_tokens': 636, 'total_tokens': 765, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E159yDsHu2Ok2Pc9PTVZh9er1832H', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f5a53-d18d-77d2-b150-758b27d4fb5a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 636, 'output_tokens': 129, 'total_tokens': 765, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'last_speaker': 'skeptic'}}
# {'optimist': {'messages': [AIMessage(content='전기차의 환경적 문제를 언급하셨지만, 이 문제는 기술 발전 및 재활용 시스템 개선을 통해 점차 해결되고 있습니다. 예를 들어, 배터리 재활용 기술이 발전함에 따라 효율적인 자원 회수와 환경 보호가 가능해지고 있으며, 여러 국가에서 이러한 기술을 적극적으로 채택하고 있습니다.\n\n결국 전기차는 인류가 화석 연료 의존도를 줄이고 지속 가능한 미래로 나아가는 중요한 단계이며, 이로 인해 기존의 문제들을 개선해 나갈 수 있는 기회를 제공합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 125, 'prompt_tokens': 768, 'total_tokens': 893, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8c62eb5aea', 'id': 'chatcmpl-E15A1C1rRO0Jw4937ZgFjF51OgFaS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f5a53-dca0-7e13-894c-66954e3c0585-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 768, 'output_tokens': 125, 'total_tokens': 893, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'last_speaker': 'optimist', 'turn_count': 3}}
# {'skeptic': {'messages': [AIMessage(content='기술 발전이 있더라도 전기차의 환경적 영향과 상관없이 여전히 자원 고갈과 생태계 파괴의 우려는 남아 있습니다. 특히 리튬, 코발트 등의 자원 채굴은 환경에 심각한 영향을 미치고 있으며, 이러한 문제가 해결되지 않는 한 민간 및 기업 차원에서 전기차 도입의 심각한 한계를 인정해야 합니다. \n\n게다가 기술 발전의 속도가 실제 시장에서 발생하는 변화를 따라잡지 못하는 경우도 빈번하므로, 기술적 해결책만으로 모든 문제가 해결될 수는 없다는 점을 강조하고 싶습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 140, 'prompt_tokens': 896, 'total_tokens': 1036, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1aec1bbdb8', 'id': 'chatcmpl-E15A4rlzbHgLLgKszH9N357LKW8wW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f5a53-e56f-7fa1-8fe1-5fe7bfa130f1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 896, 'output_tokens': 140, 'total_tokens': 1036, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'last_speaker': 'skeptic'}}

# %% [markdown]
# ## 복잡한 수학 계산 Agent 만들어보기

# %% [markdown]
# * **방식 B (`bind_tools` + `ToolNode`)** 로 수학 연산 Agent를 만듭니다.
# * LLM은 직접 계산하지 않고, tool을 조합해 사칙연산·로그·제곱·미분·적분을 수행합니다.
# * `current_number`에는 가장 최근 **수치 결과**를 저장해 중간값을 추적합니다.

# %%
from typing import Annotated, List, Optional

from langchain_core.messages import AIMessage, HumanMessage, SystemMessage, BaseMessage
from langgraph.graph.message import add_messages
from pydantic import BaseModel, Field


class CalcState(BaseModel):
    messages: Annotated[List[BaseMessage], add_messages] = Field(default_factory=list)
    current_number: Optional[float] = 0.0

# %%
# !pip install sympy -q

# %%
import math

import sympy as sp
from langchain.tools import tool


@tool
def add(a: float, b: float) -> str:
    """두 수를 더합니다. a + b"""
    return str(a + b)


@tool
def subtract(a: float, b: float) -> str:
    """두 수를 뺍니다. a - b"""
    return str(a - b)


@tool
def multiply(a: float, b: float) -> str:
    """두 수를 곱합니다. a * b"""
    return str(a * b)


@tool
def divide(a: float, b: float) -> str:
    """두 수를 나눕니다. a / b. b가 0이면 오류 메시지를 반환합니다."""
    if b == 0:
        return '오류: 0으로 나눌 수 없습니다.'
    return str(a / b)


@tool
def power(base: float, exponent: float) -> str:
    """거듭제곱을 계산합니다. base ** exponent (예: 2^3 → base=2, exponent=3)"""
    return str(base ** exponent)


@tool
def logarithm(x: float, base: float = math.e) -> str:
    """로그를 계산합니다. log_base(x). base 기본값은 자연상수 e(자연로그). 상용로그는 base=10."""
    if x <= 0:
        return '오류: 로그의 진수는 양수여야 합니다.'
    if base <= 0 or base == 1:
        return '오류: 밑은 1이 아닌 양수여야 합니다.'
    return str(math.log(x, base))


@tool
def differentiate(expression: str, variable: str = 'x') -> str:
    """수식을 미분합니다. expression은 문자열 수식(예: 'x**2 + 3*x'), variable은 미분 변수(기본 'x')."""
    try:
        var = sp.symbols(variable)
        expr = sp.sympify(expression)
        return str(sp.diff(expr, var))
    except Exception as e:
        return f'미분 오류: {e}'


@tool
def integrate_expr(expression: str, variable: str = 'x') -> str:
    """수식을 부정적분합니다. expression은 문자열 수식(예: '2*x + 1'), variable은 적분 변수(기본 'x')."""
    try:
        var = sp.symbols(variable)
        expr = sp.sympify(expression)
        return str(sp.integrate(expr, var))
    except Exception as e:
        return f'적분 오류: {e}'


@tool
def definite_integrate(expression: str, lower: float, upper: float, variable: str = 'x') -> str:
    """정적분을 계산합니다. ∫_lower^upper expression d(variable)."""
    try:
        var = sp.symbols(variable)
        expr = sp.sympify(expression)
        result = sp.integrate(expr, (var, lower, upper))
        return str(result.evalf())
    except Exception as e:
        return f'정적분 오류: {e}'


@tool
def evaluate(expression: str) -> str:
    """문자열 수식을 수치로 계산합니다. 예: 'sin(pi/2) + sqrt(4)', '2**10 + log(10)'."""
    try:
        result = sp.sympify(expression).evalf()
        return str(result)
    except Exception as e:
        return f'계산 오류: {e}'


MATH_TOOLS = [
    add, subtract, multiply, divide,
    power, logarithm,
    differentiate, integrate_expr, definite_integrate,
    evaluate,
]
print('등록된 tool:', [t.name for t in MATH_TOOLS])
# Out:
# 등록된 tool: ['add', 'subtract', 'multiply', 'divide', 'power', 'logarithm', 'differentiate', 'integrate_expr', 'definite_integrate', 'evaluate']

# %% [markdown]
# ### Agent + ToolNode
#
# * `agent`: `bind_tools` LLM이 필요하면 `tool_calls`를 내고, 아니면 최종 답변
# * `tools`: tool 실행 후 결과가 `messages`에 추가되고, 숫자면 `current_number` 갱신
# * tool 결과가 있으면 다시 `agent`로 돌아가 해석·추가 연산 (ReAct 루프)

# %%
from langchain_openai import ChatOpenAI
from langgraph.graph import END, START, StateGraph
from langgraph.prebuilt import ToolNode, tools_condition

calc_llm = ChatOpenAI(model='gpt-5-nano', temperature=0, api_key=OPENAI_API_KEY)
calc_llm_with_tools = calc_llm.bind_tools(MATH_TOOLS)

CALC_SYSTEM = SystemMessage(content=(
    '당신은 수학 연산 전문 Agent입니다. '
    '직접 암산하지 말고, 반드시 제공된 tool로 계산하세요. '
    '복잡한 문제는 여러 tool을 단계적으로 호출해 중간 결과를 이어 쓰세요. '
    '미분·적분은 수식 문자열로 tool에 넘기세요 (예: x**2 + 3*x). '
    '모든 계산이 끝나면 tool 없이 최종 답만 한국어로 짧게 설명하세요.'
))


def calc_agent_node(state: CalcState) -> dict:
    prompts = [CALC_SYSTEM, *state.messages]
    response = calc_llm_with_tools.invoke(prompts)
    return {'messages': [response]}


def _try_parse_float(text: str) -> float | None:
    try:
        return float(sp.N(sp.sympify(text)))
    except Exception:
        return None


_base_tool_node = ToolNode(MATH_TOOLS)


def calc_tools_node(state: CalcState) -> dict:
    """ToolNode 실행 후, 마지막 tool 결과가 숫자면 current_number를 갱신합니다."""
    result = _base_tool_node.invoke(state)
    updates = {'messages': result['messages']}
    last = result['messages'][-1]
    parsed = _try_parse_float(str(last.content))
    if parsed is not None:
        updates['current_number'] = parsed
        print(f'[current_number 갱신] {parsed}')
    return updates


calc_workflow = StateGraph(CalcState)
calc_workflow.add_node('agent', calc_agent_node)
calc_workflow.add_node('tools', calc_tools_node)

calc_workflow.add_edge(START, 'agent')
# tools_condition: tool_calls 있으면 'tools', 없으면 END
calc_workflow.add_conditional_edges('agent', tools_condition)
calc_workflow.add_edge('tools', 'agent')

calc_app = calc_workflow.compile()
calc_app

# %% [markdown]
# ### 실행 예시
#
# 여러 tool을 연쇄 호출하는지, `current_number`가 갱신되는지 확인합니다.

# %%
def run_calc(question: str) -> CalcState:
    init = CalcState(messages=[HumanMessage(content=question)], current_number=0.0)
    final = calc_app.invoke(init)
    print('질문:', question)
    print('최종 current_number:', final['current_number'])
    print('최종 답변:', final['messages'][-1].content)
    return final


# 사칙연산 + 제곱
_ = run_calc('(3 + 5) * 2^4 을 계산해줘')
# Out:
# [current_number 갱신] 16.0
# [current_number 갱신] 128.0
# 질문: (3 + 5) * 2^4 을 계산해줘
# 최종 current_number: 128.0
# 최종 답변: 결과: 128
#
# (해설) 계산 과정: 먼저 (3+5)=8, 그리고 2^4=16을 구한 뒤 곱하면 8*16=128.

# %%
# 로그 + 미분 + 정적분
_ = run_calc('ln(e^2) 값을 구한 뒤, x^3 을 x에 대해 미분하고, 그 결과를 0부터 1까지 정적분한 값을 알려줘')
# Out:
# [current_number 갱신] 2.0
# [current_number 갱신] 2.0
# [current_number 갱신] 2.0
# [current_number 갱신] 2.0
# [current_number 갱신] 2.0
# [current_number 갱신] 2.0
# [current_number 갱신] 2.0
# [current_number 갱신] 1.0
# 질문: ln(e^2) 값을 구한 뒤, x^3 을 x에 대해 미분하고, 그 결과를 0부터 1까지 정적분한 값을 알려줘
# 최종 current_number: 1.0
# 최종 답변: ln(e^2) = 2이며, x^3의 도함수는 3x^2이고, 그 결과를 0에서 1까지 정적분하면 1입니다.

# %%
# 스트림으로 tool 호출 과정 관찰
init = CalcState(
    messages=[HumanMessage(content='2^10 을 구한 다음, 그 값에 자연로그를 취해줘')],
    cur_number=0.0,
)
for chunk in calc_app.stream(init):
    print(chunk)
    print('---')
# Out:
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 795, 'prompt_tokens': 660, 'total_tokens': 1455, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E13B9XMMeFEoNaNHdD1xTafVfBneT', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f59df-9f75-7ad1-951b-1a9e74b799fd-0', tool_calls=[{'name': 'power', 'args': {'base': 2, 'exponent': 10}, 'id': 'call_BmK7FBFeiPfag9NGsVePjHUI', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 660, 'output_tokens': 795, 'total_tokens': 1455, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})]}}
# ---
# [current_number 갱신] 1024.0
# {'tools': {'messages': [ToolMessage(content='1024.0', name='power', id='a5befa1b-a182-46ad-bfc9-3b7b9ed50feb', tool_call_id='call_BmK7FBFeiPfag9NGsVePjHUI')], 'current_number': 1024.0}}
# ---
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 695, 'total_tokens': 724, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E13BJuWFrz63RFyI0vI7sk7oNKFGs', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f59df-c4df-7740-b11d-d2010a44dbd9-0', tool_calls=[{'name': 'logarithm', 'args': {'x': 1024, 'base': 2.718281828459045}, 'id': 'call_GtTINrbZIJ1s1Myd0UGO2XB3', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 695, 'output_tokens': 29, 'total_tokens': 724, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ---
# [current_number 갱신] 6.931471805599453
# {'tools': {'messages': [ToolMessage(content='6.931471805599453', name='logarithm', id='ab8d8dad-1652-4ec4-8b17-f4c392cf1afb', tool_call_id='call_GtTINrbZIJ1s1Myd0UGO2XB3')], 'current_number': 6.931471805599453}}
# ---
# {'agent': {'messages': [AIMessage(content='2^10은 1024이고, 그 값의 자연로그는 ln(1024) ≈ 6.9314718056입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 361, 'prompt_tokens': 743, 'total_tokens': 1104, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E13BKq5TFl2DzPXfnjA5tbxqqYJBs', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f59df-ca1d-7380-83cc-474466404a67-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 743, 'output_tokens': 361, 'total_tokens': 1104, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})]}}
# ---

# %% [markdown]
# ## Sub-Graph
# * compile한 그래프를 Node퍼럼 활용해 새로운 `workflow`를 구성할 수 있습니다.
# * 복잡한 기능을 수행하는 `Graph`를 만들고, `Node`로 상위 네트워크를 구성하면 더욱 복잡한 flow 구성이 가능합니다

# %%
calc_app

# %%
llm = ChatOpenAI(model="gpt-5-nano")

# %%
def formulate_node(state: CalcState):
    messages = [
        SystemMessage(content="아래 문제 상황을 수식으로 변환하여 출력하세요. 전체 계산식만 출력하고 절대 계산하지 마세요."),
        *state.messages]
    response = llm.invoke(messages)
    return {"messages": response}

def final_answer(state: CalcState):
    messages = [
        SystemMessage(content="앞선 계산 과정을 정리해 사용자의 맨 처음 질문에 답변하세요."),
        *state.messages]
    response = llm.invoke(messages)
    return {"messages": response}

# %%
workflow = StateGraph(CalcState)

workflow.add_node("formulate", formulate_node)
workflow.add_node("calculate", calc_app)
workflow.add_node("answer", final_answer)

workflow.add_edge(START, "formulate")
workflow.add_edge("formulate", "calculate")
workflow.add_edge("calculate", "answer")
workflow.add_edge("answer", END)


final_app = workflow.compile()
final_app

# %%
init_state = CalcState(messages=[HumanMessage(content="매주 1%씩 주식 수익 내면 1년 뒤 총 수익은?")])

for chunk in final_app.stream(init_state):
    print(chunk)
# Out:
# {'formulate': {'messages': AIMessage(content='총 수익 = (1 + 0.01)^{52} - 1', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 923, 'prompt_tokens': 58, 'total_tokens': 981, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E13BRJNwygU3LYithdy4ouLIyBzXF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f59df-e3a9-7223-96e2-7536a0e538bb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 58, 'output_tokens': 923, 'total_tokens': 981, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}})}}
# [current_number 갱신] 1.6776889214629447
# [current_number 갱신] -0.6776889214629447
# {'calculate': {'messages': [HumanMessage(content='매주 1%씩 주식 수익 내면 1년 뒤 총 수익은?', additional_kwargs={}, response_metadata={}, id='0b3e7009-d891-462d-8681-d12864889b4c'), AIMessage(content='총 수익 = (1 + 0.01)^{52} - 1', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 923, 'prompt_tokens': 58, 'total_tokens': 981, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E13BRJNwygU3LYithdy4ouLIyBzXF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f59df-e3a9-7223-96e2-7536a0e538bb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 58, 'output_tokens': 923, 'total_tokens': 981, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 992, 'prompt_tokens': 688, 'total_tokens': 1680, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 960, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E13BbCf33k3OMEn1eD1wB8zjejM7t', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f59e0-0b9c-74f2-8114-47b1eab348da-0', tool_calls=[{'name': 'power', 'args': {'base': 1.01, 'exponent': 52}, 'id': 'call_aw2Gjj2bhc3c2sxxxn3dQuOV', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 688, 'output_tokens': 992, 'total_tokens': 1680, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 960}}), ToolMessage(content='1.6776889214629447', name='power', id='9f52cf50-ac3e-44a3-ac77-19aa6e540427', tool_call_id='call_aw2Gjj2bhc3c2sxxxn3dQuOV'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 729, 'total_tokens': 756, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E13BlhG6zYM73NmvuwriQ42tk3GRi', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f59e0-3302-7992-a2a9-ef7928154280-0', tool_calls=[{'name': 'subtract', 'args': {'a': 1, 'b': 1.6776889214629447}, 'id': 'call_aS1fAeccBYxxXY5tpXhRD0Ve', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 729, 'output_tokens': 27, 'total_tokens': 756, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='-0.6776889214629447', name='subtract', id='b8465474-54ff-472e-865d-424e2e913358', tool_call_id='call_aS1fAeccBYxxXY5tpXhRD0Ve'), AIMessage(content='1년 뒤 총 수익은 약 67.77%입니다. 즉, (1.01)^52 − 1 ≈ 0.677689.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 555, 'prompt_tokens': 775, 'total_tokens': 1330, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E13BmxVTER7YZjGjRJ4vK5OIkabIi', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f59e0-3 ...
# {'answer': {'messages': AIMessage(content='다음과 같이 정리하면 됩니다.\n\n- 가정: 주간 수익률 1% = 0.01, 매주 복리로 52주\n- 총 수익률 공식: 총 수익률 = (1 + 0.01)^{52} - 1\n- 계산: (1.01)^{52} ≈ 1.6776889214629447\n- 따라서 총 수익률 ≈ 1.6776889214629447 − 1 = 0.6776889214629447\n- 이를 퍼센트로: 약 67.77%\n\n요약: 1년 뒤 총 수익은 약 67.77%입니다. (즉, 원금의 약 1.6777배가 됨)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1136, 'prompt_tokens': 201, 'total_tokens': 1337, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 960, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E13BsY0p23EcXA80AKG8Z2Q24R8cN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f59e0-4f5f-7d43-b454-8ea9d6531753-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 201, 'output_tokens': 1136, 'total_tokens': 1337, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 960}})}}
