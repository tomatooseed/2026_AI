# %% [markdown]
# # 02. NumPy + Maze 실습
# **SK하이닉스 Autonomous R&D — Day 1**
#
# ### 학습 목표
# - 배열(ndarray) 개념을 이해하고 기본 연산을 수행할 수 있다
# - 반복문·조건문·함수·배열을 하나의 문제에 통합해서 사용할 수 있다

# %%
# 데이터 경로 설정
import os
from google.colab import drive

drive.mount('/content/drive')

BASE = '/content/drive/MyDrive/SK Autonomous R&D'

# dataset 폴더가 없으면 zip 압축 해제
if not os.path.exists(f'{BASE}/dataset'):
    if os.path.exists(f'{BASE}/dataset.zip'):
        print('dataset.zip 압축 해제 중...')
        os.system(f'unzip -q "{BASE}/dataset.zip" -d "{BASE}"')
        print('완료')
    else:
        print('⚠️  dataset.zip 을 SK Autonomous R&D 폴더에 업로드하세요.')

DATA_DIR = f'{BASE}/dataset'
print(f'DATA_DIR = {DATA_DIR}')

# %% [markdown]
# ---
# ## 1. NumPy 배열 기초
# NumPy는 수치 데이터를 빠르게 처리하는 라이브러리입니다.
# 센서 데이터, 수율 배열 처리에 필수입니다.

# %%
# 기초 통계량

# %%
# 2D 배열 — 센서 데이터 (행:Lot, 열:센서)

# %%
# axis=0: 열 방향(센서별), axis=1: 행 방향(Lot별)

# %%
# 랜덤 배열

# %%
# 조건 필터링

# %% [markdown]
# ---
# ## 2. Maze 실습
# 지금까지 배운 `for`, `if`, `함수`, `배열`, `시각화`를 한 번에 씁니다.
# 이 실습을 이해하면  알고리즘 코드를 읽을 수 있습니다.
# https://docs.google.com/spreadsheets/d/1rdTItkyKjmi3zR3fBjvoBm5cjwXpPtHpesS85kMkuyM/edit?gid=0#gid=0

# %%
# Step 1: Empty Maze (0=길, 1=벽)

# %%
# Step 2: 외벽 만들기

# %%
# Step 3: 랜덤 내부 벽 (인접 벽 ≤1개일 때만 추가)

# %%
# 함수로 만들기 — 재사용 가능

# %%
# Step 4: 랜덤 워크 — 10000번 이동

# %%
# Step 5: 목적지까지 최단 경로# while + 백트래킹 — 이미 지나온 곳을 다시 가면 경로를 되돌린다

# %% [markdown]
# ---
# ## ✅ Maze에서 사용한 문법 정리
#
# | 문법 | 사용한 곳 |
# |------|----------|
# | `np.zeros` | 미로 배열 초기화 |
# | `for` | 외벽·내벽 생성, 경로 탐색 |
# | `if` | 벽 조건 확인 |
# | `while` | 목표 도달까지 반복 |
# | `def` | `generate_maze()` 함수화 |
# | `list + append` | 경로 기록 |
# | `plt.imshow` | 시각화 |

# %%
# 직접 해보기# generate_maze(n=40, num_walls=200) 으로 더 큰 미로를 만들고# 목적지를 (18, 18) 로 바꿔서 경로를 찾아보세요
